# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.style.use('default')
sns.set(rc={'figure.figsize':(8, 6)})
sns.set_style('white')
sns.despine()

# %%
orel = 0
i_arr = []
p_arr = []

i_arr_2 = []
p_arr_2 = []

for i in range(1, 500):
    rand = np.random.randint(0, 2)
    if rand == 0:
        orel += 1
    i_arr.append(i)
    p_arr.append(orel / i)

orel = 0
for i in range(1, 500):
    rand = np.random.randint(0, 2)
    if rand == 0:
        orel += 1
    i_arr_2.append(i)
    p_arr_2.append(orel / i)

plt.plot(i_arr, p_arr, color = 'darkslategray')
# plt.plot(i_arr_2, p_arr_2, color = 'darkslategray')
plt.plot([0, 500], [0.5, 0.5], color = 'blue')
plt.xlabel('n')
plt.ylabel('P*(n)')
plt.show()

# %%
five_or_six = 0
i_arr = []
p_arr = []

# %%
for i in range(1, 2000):
    rand = np.random.randint(1, 7)
    if rand == 5 or rand == 6:
        five_or_six += 1
    i_arr.append(i)
    p_arr.append(five_or_six / i)

plt.plot(i_arr, p_arr, color = 'darkslategray')
plt.plot([0, 2000], [1/3, 1/3], color = 'blue')
plt.xlabel('n')
plt.ylabel('P*(n)')
plt.show()
